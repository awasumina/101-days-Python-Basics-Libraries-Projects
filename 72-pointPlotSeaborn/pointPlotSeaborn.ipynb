# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
  
data = {
    'Music': [5.0, 4.0, 5.0, 5.0, 5.0, 5.0, 4.0, 4.0, 5.0, 5.0],
    'Techno': [1.0, 1.0, 1.0, 2.0, 2.0, 3.0, 4.0, 1.0, 2.0, 3.0],
    'Movies': [5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 4.0, 5.0, 5.0],
    'History': [1.0, 1.0, 1.0, 4.0, 3.0, 4.0, 4.0, 2.0, 3.0, 2.0],
    'Mathematics': [3.0, 5.0, 5.0, 4.0, 2.0, 1.0, 5.0, 3.0, 1.0, 2.0],
    'Age': [20.0, 19.0, 20.0, 22.0, 20.0, 20.0, 27.0, 18.0, 25.0, 21.0],
    'Siblings': [1.0, 2.0, 2.0, 1.0, 1.0, 1.0, 5.0, 0.0, 1.0, 1.0],
    'Gender': ['female', 'female', 'female', 'female', 'female', 'female', 'male', 'female', 'female', 'male'],
    'Village - town': ['village', 'city', 'city', 'city', 'village', 'city', 'village', 'city', 'city', 'village'],
    'Age Category': ['Less than 21', 'Less than 21', 'Less than 21', '21+', 'Less than 21', 'Less than 21', '21+', 'Less than 21', '21+', '21+']
}

student_data = pd.DataFrame(data)

# Create a point plot of family relationship vs. absences
sns.catplot(data=student_data,x="Siblings",y="Age Category",kind="point")



# Show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'Music': [5.0, 4.0, 5.0, 5.0, 5.0, 5.0, 4.0, 4.0, 5.0, 5.0],
    'Techno': [1.0, 1.0, 1.0, 2.0, 2.0, 3.0, 4.0, 1.0, 2.0, 3.0],
    'Movies': [5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 4.0, 5.0, 5.0],
    'History': [1.0, 1.0, 1.0, 4.0, 3.0, 4.0, 4.0, 2.0, 3.0, 2.0],
    'Mathematics': [3.0, 5.0, 5.0, 4.0, 2.0, 1.0, 5.0, 3.0, 1.0, 2.0],
    'Age': [20.0, 19.0, 20.0, 22.0, 20.0, 20.0, 27.0, 18.0, 25.0, 21.0],
    'Siblings': [1.0, 2.0, 2.0, 1.0, 1.0, 1.0, 5.0, 0.0, 1.0, 1.0],
    'Gender': ['female', 'female', 'female', 'female', 'female', 'female', 'male', 'female', 'female', 'male'],
    'Village - town': ['village', 'city', 'city', 'city', 'village', 'city', 'village', 'city', 'city', 'village'],
    'Age Category': ['Less than 21', 'Less than 21', 'Less than 21', '21+', 'Less than 21', 'Less than 21', '21+', 'Less than 21', '21+', '21+']
}

student_data = pd.DataFrame(data)

# Create a point plot of family relationship vs. absences
sns.catplot(data=student_data,x="Siblings",y="Age Category",kind="point",capsize=0.2)



# Show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'Music': [5.0, 4.0, 5.0, 5.0, 5.0, 5.0, 4.0, 4.0, 5.0, 5.0],
    'Techno': [1.0, 1.0, 1.0, 2.0, 2.0, 3.0, 4.0, 1.0, 2.0, 3.0],
    'Movies': [5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 4.0, 5.0, 5.0],
    'History': [1.0, 1.0, 1.0, 4.0, 3.0, 4.0, 4.0, 2.0, 3.0, 2.0],
    'Mathematics': [3.0, 5.0, 5.0, 4.0, 2.0, 1.0, 5.0, 3.0, 1.0, 2.0],
    'Age': [20.0, 19.0, 20.0, 22.0, 20.0, 20.0, 27.0, 18.0, 25.0, 21.0],
    'Siblings': [1.0, 2.0, 2.0, 1.0, 1.0, 1.0, 5.0, 0.0, 1.0, 1.0],
    'Gender': ['female', 'female', 'female', 'female', 'female', 'female', 'male', 'female', 'female', 'male'],
    'Village - town': ['village', 'city', 'city', 'city', 'village', 'city', 'village', 'city', 'city', 'village'],
    'Age Category': ['Less than 21', 'Less than 21', 'Less than 21', '21+', 'Less than 21', 'Less than 21', '21+', 'Less than 21', '21+', '21+']
}

student_data = pd.DataFrame(data)

# Create a point plot of family relationship vs. absences
sns.catplot(data=student_data,x="Siblings",y="Age Category",kind="point",capsize=0.2,join=False)



# Show plot
plt.show()
# Out:
# <ipython-input-9-e4c6115e86f5>:21: UserWarning:
#
# The `join` parameter is deprecated and will be removed in v0.15.0. You can remove the line between points with `linestyle='none'`.
#
#   sns.catplot(data=student_data,x="Siblings",y="Age Category",kind="point",capsize=0.2,join=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'Music': [5.0, 4.0, 5.0, 5.0, 5.0, 5.0, 4.0, 4.0, 5.0, 5.0],
    'Techno': [1.0, 1.0, 1.0, 2.0, 2.0, 3.0, 4.0, 1.0, 2.0, 3.0],
    'Movies': [5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 4.0, 5.0, 5.0],
    'History': [1.0, 1.0, 1.0, 4.0, 3.0, 4.0, 4.0, 2.0, 3.0, 2.0],
    'Mathematics': [3.0, 5.0, 5.0, 4.0, 2.0, 1.0, 5.0, 3.0, 1.0, 2.0],
    'Age': [20.0, 19.0, 20.0, 22.0, 20.0, 20.0, 27.0, 18.0, 25.0, 21.0],
    'Siblings': [1.0, 2.0, 2.0, 1.0, 1.0, 1.0, 5.0, 0.0, 1.0, 1.0],
    'Gender': ['female', 'female', 'female', 'female', 'female', 'female', 'male', 'female', 'female', 'male'],
    'Village - town': ['village', 'city', 'city', 'city', 'village', 'city', 'village', 'city', 'city', 'village'],
    'Age Category': ['Less than 21', 'Less than 21', 'Less than 21', '21+', 'Less than 21', 'Less than 21', '21+', 'Less than 21', '21+', '21+']
}

student_data = pd.DataFrame(data)

# Create a point plot of family relationship vs. absences
sns.catplot(data=student_data,x="Siblings",y="Age Category",kind="point",
            hue="Village - town")



# Show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'Music': [5.0, 4.0, 5.0, 5.0, 5.0, 5.0, 4.0, 4.0, 5.0, 5.0],
    'Techno': [1.0, 1.0, 1.0, 2.0, 2.0, 3.0, 4.0, 1.0, 2.0, 3.0],
    'Movies': [5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 4.0, 5.0, 5.0],
    'History': [1.0, 1.0, 1.0, 4.0, 3.0, 4.0, 4.0, 2.0, 3.0, 2.0],
    'Mathematics': [3.0, 5.0, 5.0, 4.0, 2.0, 1.0, 5.0, 3.0, 1.0, 2.0],
    'Age': [20.0, 19.0, 20.0, 22.0, 20.0, 20.0, 27.0, 18.0, 25.0, 21.0],
    'Siblings': [1.0, 2.0, 2.0, 1.0, 1.0, 1.0, 5.0, 0.0, 1.0, 1.0],
    'Gender': ['female', 'female', 'female', 'female', 'female', 'female', 'male', 'female', 'female', 'male'],
    'Village - town': ['village', 'city', 'city', 'city', 'village', 'city', 'village', 'city', 'city', 'village'],
    'Age Category': ['Less than 21', 'Less than 21', 'Less than 21', '21+', 'Less than 21', 'Less than 21', '21+', 'Less than 21', '21+', '21+']
}

student_data = pd.DataFrame(data)

# Create a point plot of family relationship vs. absences
sns.catplot(data=student_data,x="Siblings",y="Age Category",kind="point",
            hue="Village - town",ci=None)



# Show plot
plt.show()
# Out:
# <ipython-input-12-6ac655bac41d>:21: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.catplot(data=student_data,x="Siblings",y="Age Category",kind="point",

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'Music': [5.0, 4.0, 5.0, 5.0, 5.0, 5.0, 4.0, 4.0, 5.0, 5.0],
    'Techno': [1.0, 1.0, 1.0, 2.0, 2.0, 3.0, 4.0, 1.0, 2.0, 3.0],
    'Movies': [5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 4.0, 5.0, 5.0],
    'History': [1.0, 1.0, 1.0, 4.0, 3.0, 4.0, 4.0, 2.0, 3.0, 2.0],
    'Mathematics': [3.0, 5.0, 5.0, 4.0, 2.0, 1.0, 5.0, 3.0, 1.0, 2.0],
    'Age': [20.0, 19.0, 20.0, 22.0, 20.0, 20.0, 27.0, 18.0, 25.0, 21.0],
    'Siblings': [1.0, 2.0, 2.0, 1.0, 1.0, 1.0, 5.0, 0.0, 1.0, 1.0],
    'Gender': ['female', 'female', 'female', 'female', 'female', 'female', 'male', 'female', 'female', 'male'],
    'Village - town': ['village', 'city', 'city', 'city', 'village', 'city', 'village', 'city', 'city', 'village'],
    'Age Category': ['Less than 21', 'Less than 21', 'Less than 21', '21+', 'Less than 21', 'Less than 21', '21+', 'Less than 21', '21+', '21+']
}

student_data = pd.DataFrame(data)

# Create a point plot of family relationship vs. absences
sns.catplot(data=student_data,x="Siblings",y="Age Category",kind="point",
            hue="Village - town",ci=None,estimator='median')



# Show plot
plt.show()
# Out:
# <ipython-input-14-44d37c2d36fe>:21: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.catplot(data=student_data,x="Siblings",y="Age Category",kind="point",
