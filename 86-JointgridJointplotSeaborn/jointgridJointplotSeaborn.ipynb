# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Data from the provided information
data = {
    'dteday': ['2011-01-01', '2011-01-02', '2011-01-03', '2011-01-04', '2011-01-05'],
    'season': [1, 1, 1, 1, 1],
    'yr': [0, 0, 0, 0, 0],
    'mnth': [1, 1, 1, 1, 1],
    'holiday': [0, 0, 0, 0, 0],
    'hum': [0.806, 0.696, 0.437, 0.59, 0.437],
    'windspeed': [0.16, 0.249, 0.248, 0.16, 0.187],
    'casual': [331, 131, 120, 108, 82],
    'registered': [654, 670, 1229, 1454, 1518],
    'total_rentals': [985, 801, 1349, 1562, 1600]
}

df = pd.DataFrame(data)

# Build a JointGrid comparing humidity and total_rentals

sns.set_style("whitegrid")
g = sns.JointGrid(x="hum", y="total_rentals", data=df, xlim=(0.1, 1.0))

# Plot the data on the JointGrid
g.plot(sns.regplot, sns.histplot)


plt.show()
plt.clf()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = {
    'dteday': ['2011-01-01', '2011-01-02', '2011-01-03', '2011-01-04', '2011-01-05'],
    'season': [1, 1, 1, 1, 1],
    'yr': [0, 0, 0, 0, 0],
    'mnth': [1, 1, 1, 1, 1],
    'holiday': [0, 0, 0, 0, 0],
    'hum': [0.806, 0.696, 0.437, 0.59, 0.437],
    'windspeed': [0.16, 0.249, 0.248, 0.16, 0.187],
    'casual': [331, 131, 120, 108, 82],
    'registered': [654, 670, 1229, 1454, 1518],
    'total_rentals': [985, 801, 1349, 1562, 1600]
}
df = pd.DataFrame(data)

# Create a jointplot similar to the JointGrid
sns.jointplot(x="hum",
        y="total_rentals",
        kind='reg',
        data=df)

plt.show()
plt.clf()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Define the data as a dictionary
data = {
    'dteday': ['2011-01-01', '2011-01-02', '2011-01-03', '2011-01-04', '2011-01-05'],
    'season': [1, 1, 1, 1, 1],
    'yr': [0, 0, 0, 0, 0],
    'mnth': [1, 1, 1, 1, 1],
    'holiday': [0, 0, 0, 0, 0],
    'weekday': [6, 0, 1, 2, 3],
    'workingday': [0, 0, 1, 1, 1],
    'weathersit': [2, 2, 1, 1, 1],
    'temp': [0.344167, 0.363478, 0.196364, 0.2, 0.226957],
    'atemp': [0.363625, 0.353739, 0.189405, 0.212122, 0.22927],
    'hum': [0.805833, 0.696087, 0.437273, 0.590435, 0.436957],
    'windspeed': [0.160446, 0.248539, 0.248309, 0.160296, 0.1869],
    'casual': [331, 131, 120, 108, 82],
    'registered': [654, 670, 1229, 1454, 1518],
    'total_rentals': [985, 801, 1349, 1562, 1600]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Plot temp vs. total_rentals as a regression plot
sns.jointplot(x="temp",
         y="total_rentals",
         kind='reg',
         data=df,
         order=2,
         xlim=(0, 1))

plt.show()
plt.clf()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py:261: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Define the data as a dictionary
data = {
    'dteday': ['2011-01-01', '2011-01-02', '2011-01-03', '2011-01-04', '2011-01-05'],
    'season': [1, 1, 1, 1, 1],
    'yr': [0, 0, 0, 0, 0],
    'mnth': [1, 1, 1, 1, 1],
    'holiday': [0, 0, 0, 0, 0],
    'weekday': [6, 0, 1, 2, 3],
    'workingday': [0, 0, 1, 1, 1],
    'weathersit': [2, 2, 1, 1, 1],
    'temp': [0.344167, 0.363478, 0.196364, 0.2, 0.226957],
    'atemp': [0.363625, 0.353739, 0.189405, 0.212122, 0.22927],
    'hum': [0.805833, 0.696087, 0.437273, 0.590435, 0.436957],
    'windspeed': [0.160446, 0.248539, 0.248309, 0.160296, 0.1869],
    'casual': [331, 131, 120, 108, 82],
    'registered': [654, 670, 1229, 1454, 1518],
    'total_rentals': [985, 801, 1349, 1562, 1600]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Plot a jointplot showing the residuals
sns.jointplot(x="temp",
        y="total_rentals",
        kind='resid',
        data=df,
        order=2)

plt.show()
plt.clf()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Define the data as a dictionary
data = {
    'dteday': ['2011-01-01', '2011-01-02', '2011-01-03', '2011-01-04', '2011-01-05'],
    'season': [1, 1, 1, 1, 1],
    'yr': [0, 0, 0, 0, 0],
    'mnth': [1, 1, 1, 1, 1],
    'holiday': [0, 0, 0, 0, 0],
    'weekday': [6, 0, 1, 2, 3],
    'workingday': [0, 0, 1, 1, 1],
    'weathersit': [2, 2, 1, 1, 1],
    'temp': [0.344167, 0.363478, 0.196364, 0.2, 0.226957],
    'atemp': [0.363625, 0.353739, 0.189405, 0.212122, 0.22927],
    'hum': [0.805833, 0.696087, 0.437273, 0.590435, 0.436957],
    'windspeed': [0.160446, 0.248539, 0.248309, 0.160296, 0.1869],
    'casual': [331, 131, 120, 108, 82],
    'registered': [654, 670, 1229, 1454, 1518],
    'total_rentals': [985, 801, 1349, 1562, 1600]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Create a jointplot of temp vs. casual riders
# Include a kdeplot over the scatter plot
g = sns.jointplot(x="temp",
             y="casual",
             kind='scatter',
             data=df,
             marginal_kws=dict(bins=10))
g.plot_joint(sns.kdeplot)

plt.show()
plt.clf()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Define the data as a dictionary
data = {
    'dteday': ['2011-01-01', '2011-01-02', '2011-01-03', '2011-01-04', '2011-01-05'],
    'season': [1, 1, 1, 1, 1],
    'yr': [0, 0, 0, 0, 0],
    'mnth': [1, 1, 1, 1, 1],
    'holiday': [0, 0, 0, 0, 0],
    'weekday': [6, 0, 1, 2, 3],
    'workingday': [0, 0, 1, 1, 1],
    'weathersit': [2, 2, 1, 1, 1],
    'temp': [0.344167, 0.363478, 0.196364, 0.2, 0.226957],
    'atemp': [0.363625, 0.353739, 0.189405, 0.212122, 0.22927],
    'hum': [0.805833, 0.696087, 0.437273, 0.590435, 0.436957],
    'windspeed': [0.160446, 0.248539, 0.248309, 0.160296, 0.1869],
    'casual': [331, 131, 120, 108, 82],
    'registered': [654, 670, 1229, 1454, 1518],
    'total_rentals': [985, 801, 1349, 1562, 1600]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Replicate the above plot but only for registered riders
g = sns.jointplot(x="temp",
             y="registered",
             kind='scatter',
             data=df,
             marginal_kws=dict(bins=10))
g.plot_joint(sns.kdeplot)

plt.show()
plt.clf()
