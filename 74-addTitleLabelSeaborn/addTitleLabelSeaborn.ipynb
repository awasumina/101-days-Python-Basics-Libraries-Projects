# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Define the data as a dictionary
data = {
    'mpg': [18.0, 15.0, 18.0, 16.0, 17.0, 27.0, 44.0, 32.0, 28.0, 31.0],
    'cylinders': [8, 8, 8, 8, 8, 4, 4, 4, 4, 4],
    'displacement': [307.0, 350.0, 318.0, 304.0, 302.0, 140.0, 97.0, 135.0, 120.0, 119.0],
    'horsepower': [130.0, 165.0, 150.0, 150.0, 140.0, 86.0, 52.0, 84.0, 79.0, 82.0],
    'weight': [3504, 3693, 3436, 3433, 3449, 2790, 2130, 2295, 2625, 2720],
    'acceleration': [12.0, 11.5, 11.0, 12.0, 10.5, 15.6, 24.6, 11.6, 18.6, 19.4],
    'model_year': [70, 70, 70, 70, 70, 82, 82, 82, 82, 82],
    'origin': ['usa', 'usa', 'usa', 'usa', 'usa', 'usa', 'europe', 'usa', 'usa', 'usa'],
    'name': [
        'chevrolet chevelle malibu', 'buick skylark 320', 'plymouth satellite',
        'amc rebel sst', 'ford torino', 'ford mustang gl', 'vw pickup',
        'dodge rampage', 'ford ranger', 'chevy s-10'
    ]
}

# Create a DataFrame
mpg = pd.DataFrame(data)

# Create scatter plot
g = sns.relplot(x="weight",
                y="horsepower",
                data=mpg,
                kind="scatter")

# Identify plot type
type_of_g = type(g)

# Print type
print(type_of_g)
# Out:
# <class 'seaborn.axisgrid.FacetGrid'>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Define the data as a dictionary
data = {
    'mpg': [18.0, 15.0, 18.0, 16.0, 17.0, 27.0, 44.0, 32.0, 28.0, 31.0],
    'cylinders': [8, 8, 8, 8, 8, 4, 4, 4, 4, 4],
    'displacement': [307.0, 350.0, 318.0, 304.0, 302.0, 140.0, 97.0, 135.0, 120.0, 119.0],
    'horsepower': [130.0, 165.0, 150.0, 150.0, 140.0, 86.0, 52.0, 84.0, 79.0, 82.0],
    'weight': [3504, 3693, 3436, 3433, 3449, 2790, 2130, 2295, 2625, 2720],
    'acceleration': [12.0, 11.5, 11.0, 12.0, 10.5, 15.6, 24.6, 11.6, 18.6, 19.4],
    'model_year': [70, 70, 70, 70, 70, 82, 82, 82, 82, 82],
    'origin': ['usa', 'usa', 'usa', 'usa', 'usa', 'usa', 'europe', 'usa', 'usa', 'usa'],
    'name': [
        'chevrolet chevelle malibu', 'buick skylark 320', 'plymouth satellite',
        'amc rebel sst', 'ford torino', 'ford mustang gl', 'vw pickup',
        'dodge rampage', 'ford ranger', 'chevy s-10'
    ]
}

# Create a DataFrame
mpg = pd.DataFrame(data)

# Create scatter plot
g = sns.relplot(x="weight",
                y="horsepower",
                data=mpg,
                kind="scatter")

# Add a title "Car Weight vs. Horsepower"

g.fig.suptitle("Car Weight vs. Horsepower")
# Show plot
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


data = {
    "Unnamed: 0": list(range(39)),
    "model_year": [70, 70, 70, 71, 71, 71, 72, 72, 72, 73, 73, 73, 74, 74, 74, 75, 75, 75, 76, 76, 76, 77, 77, 77, 78, 78, 78, 79, 79, 79, 80, 80, 80, 81, 81, 81, 82, 82, 82],
    "origin": ["europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa"],
    "mpg_mean": [25.2, 25.5, 15.273, 28.75, 29.5, 18.1, 22.0, 24.2, 16.278, 24.0, 20.0, 15.034, 27.0, 29.333, 18.333, 24.5, 27.5, 17.55, 24.25, 28.0, 19.432, 29.25, 27.417, 20.722, 24.95, 29.688, 21.773, 30.45, 32.95, 23.478, 37.289, 35.4, 25.914, 31.575, 32.958, 27.531, 40.0, 34.889, 29.45]
}

mpg_mean = pd.DataFrame(data)


# Create line plot
g = sns.lineplot(x="model_year", y="mpg_mean",
                 data=mpg_mean,
                 hue="origin")

# Add a title "Average MPG Over Time"
g.set_title("Average MPG Over Time")

# Show plot
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


data = {
    "Unnamed: 0": list(range(39)),
    "model_year": [70, 70, 70, 71, 71, 71, 72, 72, 72, 73, 73, 73, 74, 74, 74, 75, 75, 75, 76, 76, 76, 77, 77, 77, 78, 78, 78, 79, 79, 79, 80, 80, 80, 81, 81, 81, 82, 82, 82],
    "origin": ["europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa"],
    "mpg_mean": [25.2, 25.5, 15.273, 28.75, 29.5, 18.1, 22.0, 24.2, 16.278, 24.0, 20.0, 15.034, 27.0, 29.333, 18.333, 24.5, 27.5, 17.55, 24.25, 28.0, 19.432, 29.25, 27.417, 20.722, 24.95, 29.688, 21.773, 30.45, 32.95, 23.478, 37.289, 35.4, 25.914, 31.575, 32.958, 27.531, 40.0, 34.889, 29.45]
}

mpg_mean = pd.DataFrame(data)

# Create line plot
g = sns.lineplot(x="model_year", y="mpg_mean",
                 data=mpg_mean,
                 hue="origin")

# Add a title "Average MPG Over Time"
g.set_title("Average MPG Over Time")

# Add x-axis and y-axis labels
g.set(xlabel="Car Model Year",ylabel="Average MPG")


# Show plot
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


data = {
    "Unnamed: 0": list(range(39)),
    "model_year": [70, 70, 70, 71, 71, 71, 72, 72, 72, 73, 73, 73, 74, 74, 74, 75, 75, 75, 76, 76, 76, 77, 77, 77, 78, 78, 78, 79, 79, 79, 80, 80, 80, 81, 81, 81, 82, 82, 82],
    "origin": ["europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa", "europe", "japan", "usa"],
    "mpg_mean": [25.2, 25.5, 15.273, 28.75, 29.5, 18.1, 22.0, 24.2, 16.278, 24.0, 20.0, 15.034, 27.0, 29.333, 18.333, 24.5, 27.5, 17.55, 24.25, 28.0, 19.432, 29.25, 27.417, 20.722, 24.95, 29.688, 21.773, 30.45, 32.95, 23.478, 37.289, 35.4, 25.914, 31.575, 32.958, 27.531, 40.0, 34.889, 29.45]
}

mpg_mean = pd.DataFrame(data)

# Create point plot
sns.catplot(x="origin",
            y="acceleration",
            data=mpg,
            kind="point",
            join=False,
            capsize=0.1)

# Rotate x-tick labels
plt.xticks(rotation=90)

# Show plot
plt.show()
plt.show()
# Out:
# <ipython-input-7-b439de78d714>:16: UserWarning:
#
# The `join` parameter is deprecated and will be removed in v0.15.0. You can remove the line between points with `linestyle='none'`.
#
#   sns.catplot(x="origin",
