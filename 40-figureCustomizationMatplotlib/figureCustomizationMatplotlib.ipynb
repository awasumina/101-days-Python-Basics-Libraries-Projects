# %%
import matplotlib.pyplot as plt
import pandas as pd
seattle_weather = pd.DataFrame({
    "MONTH": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"],
    "MLY-PRCP-NORMAL": [4.81, 3.31, 3.51, 2.77, 2.16, 1.63, 0.79, 0.97, 1.52, 3.41, 5.84, 5.43]
})

austin_weather = pd.DataFrame({
    "MONTH": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"],
    "MLY-PRCP-NORMAL": [2.20, 2.31, 2.78, 2.27, 4.05, 4.63, 2.44, 2.03, 2.54, 4.24, 2.94, 2.21]
})

# Use the "Solarize_Light2" style and create new Figure/Axes
plt.style.use('Solarize_Light2')
fig,ax=plt.subplots()
ax.plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"])
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
seattle_weather = pd.DataFrame({
    "MONTH": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"],
    "MLY-PRCP-NORMAL": [4.81, 3.31, 3.51, 2.77, 2.16, 1.63, 0.79, 0.97, 1.52, 3.41, 5.84, 5.43]
})

austin_weather = pd.DataFrame({
    "MONTH": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"],
    "MLY-PRCP-NORMAL": [2.20, 2.31, 2.78, 2.27, 4.05, 4.63, 2.44, 2.03, 2.54, 4.24, 2.94, 2.21]
})

# Use the "ggplot" style and create new Figure/Axes
plt.style.use("ggplot")
fig, ax=plt.subplots()
ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"])
plt.show()

# %%
#saving the figure

fig.savefig("gold_medals.png")    #gold_medals.png is name of image


fig.savefig("gold_medals.png",quality=50)   #quality-1to 100 but avoid above 95 as no compression

fig.savefig("gold_medals.png",dpi=300)


fig.set_size_inches([5,3])    # The first number sets the width of the figure on the page and the second number sets the height of the figure

# %%
# automate figures from data


# A column in a pandas DataFrame is a pandas Series object, so we can get the list of different sports present in the data by calling the unique method of that column.
sports=summer['Sport'].unique()
print("sports")   #displays the branches of sports
