# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {
    'INSTNM': [
        'Alabama A & M University', 'University of Alabama at Birmingham', 'Amridge University',
        'University of Alabama in Huntsville', 'Alabama State University'
    ],
    'OPEID': [100200, 105200, 2503400, 105500, 100500],
    'REGION': [5, 5, 5, 5, 5],
    'SAT_AVG_ALL': [850, 1147, None, 1221, 844],
    'PCTPELL': [0.725, 0.350, 0.746, 0.318, 0.757],
    'Degree_Type': ['Graduate', 'Graduate', 'Graduate', 'Graduate', 'Graduate'],
    'Ownership': ['Public', 'Public', 'Private non-profit', 'Public', 'Public'],
    'Regions': ['South East', 'South East', 'South East', 'South East', 'South East'],
    'Locales': ['City: Midsize', 'City: Midsize', 'City: Midsize', 'City: Midsize', 'City: Midsize'],
    'Locale_Short': ['City', 'City', 'City', 'City', 'City']
}

# Creating DataFrame
df = pd.DataFrame(data)

# Create FacetGrid with Degree_Type and specify the order of the rows using row_order
g2 = sns.FacetGrid(df,
             col="Degree_Type" ,row="Degree_Type",row_order=['Graduate', 'Bachelors', 'Associates', 'Certificate'])

# Map a pointplot of SAT_AVG_ALL onto the grid
g2.map(sns.pointplot, 'SAT_AVG_ALL')

# Show the plot
plt.show()
plt.clf()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:718: UserWarning: Using the pointplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {
    'INSTNM': [
        'Alabama A & M University', 'University of Alabama at Birmingham', 'Amridge University',
        'University of Alabama in Huntsville', 'Alabama State University'
    ],
    'OPEID': [100200, 105200, 2503400, 105500, 100500],
    'REGION': [5, 5, 5, 5, 5],
    'SAT_AVG_ALL': [850, 1147, None, 1221, 844],
    'PCTPELL': [0.725, 0.350, 0.746, 0.318, 0.757],
    'Degree_Type': ['Graduate', 'Graduate', 'Graduate', 'Graduate', 'Graduate'],
    'Ownership': ['Public', 'Public', 'Private non-profit', 'Public', 'Public'],
    'Regions': ['South East', 'South East', 'South East', 'South East', 'South East'],
    'Locales': ['City: Midsize', 'City: Midsize', 'City: Midsize', 'City: Midsize', 'City: Midsize'],
    'Locale_Short': ['City', 'City', 'City', 'City', 'City']
}

# Creating DataFrame
df = pd.DataFrame(data)

# Create a factor plot that contains boxplots of Tuition values
sns.catplot(data=df,
         x='Ownership',
         kind='box',
         row='Degree_Type')

plt.show()
plt.clf()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {
    'INSTNM': [
        'Alabama A & M University', 'University of Alabama at Birmingham', 'Amridge University',
        'University of Alabama in Huntsville', 'Alabama State University'
    ],
    'OPEID': [100200, 105200, 2503400, 105500, 100500],
    'REGION': [5, 5, 5, 5, 5],
    'SAT_AVG_ALL': [850, 1147, None, 1221, 844],
    'PCTPELL': [0.725, 0.350, 0.746, 0.318, 0.757],
    'Degree_Type': ['Graduate', 'Graduate', 'Graduate', 'Graduate', 'Graduate'],
    'Ownership': ['Public', 'Public', 'Private non-profit', 'Public', 'Public'],
    'Regions': ['South East', 'South East', 'South East', 'South East', 'South East'],
    'Locales': ['City: Midsize', 'City: Midsize', 'City: Midsize', 'City: Midsize', 'City: Midsize'],
    'Locale_Short': ['City', 'City', 'City', 'City', 'City']
}

# Creating DataFrame
df = pd.DataFrame(data)

# Create a facetted pointplot of Average SAT_AVG_ALL scores facetted by Degree Type
sns.catplot(data=df,
        x='SAT_AVG_ALL',
        kind='point',
        row='Degree_Type',
        row_order=['Graduate', 'Bachelors', 'Associates', 'Certificate'])

plt.show()
plt.clf()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {
    'INSTNM': [
        'Alabama A & M University', 'University of Alabama at Birmingham', 'Amridge University',
        'University of Alabama in Huntsville', 'Alabama State University'
    ],
    'OPEID': [100200, 105200, 2503400, 105500, 100500],
    'REGION': [5, 5, 5, 5, 5],
    'SAT_AVG_ALL': [850, 1147, None, 1221, 844],
    'PCTPELL': [0.725, 0.350, 0.746, 0.318, 0.757],
    'Degree_Type': ['Graduate', 'Graduate', 'Graduate', 'Graduate', 'Graduate'],
    'Ownership': ['Public', 'Public', 'Private non-profit', 'Public', 'Public'],
    'Regions': ['South East', 'South East', 'South East', 'South East', 'South East'],
    'Locales': ['City: Midsize', 'City: Midsize', 'City: Midsize', 'City: Midsize', 'City: Midsize'],
    'Locale_Short': ['City', 'City', 'City', 'City', 'City']
}

# Creating DataFrame
df = pd.DataFrame(data)

# Create a facetted pointplot of Average SAT_AVG_ALL scores facetted by Degree Type
sns.catplot(data=df,
        x='SAT_AVG_ALL',
        kind='point',
        row='Degree_Type',
        row_order=['Graduate', 'Bachelors', 'Associates', 'Certificate'])

plt.show()
plt.clf()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data to create the DataFrame
data = {
    'INSTNM': [
        'Alabama A & M University', 'University of Alabama at Birmingham', 'Amridge University',
        'University of Alabama in Huntsville', 'Alabama State University',
        'SAE Institute of Technology San Francisco', 'Rasmussen College - Overland Park',
        'National Personal Training Institute of Cleveland', 'Bay Area Medical Academy - San Jose Satellite Location',
        'High Desert Medical College'
    ],
    'OPEID': [100200, 105200, 2503400, 105500, 100500, 4205801, 869423, 4220901, 4223701, 4228101],
    'REGION': [5, 5, 5, 5, 5, 8, 4, 3, 8, 8],
    'SAT_AVG_ALL': [850, 1147, None, 1221, 844, None, None, None, None, None],
    'PCTPELL': [0.725, 0.350, 0.746, 0.318, 0.757, None, None, None, None, None],
    'Degree_Type': ['Graduate', 'Graduate', 'Graduate', 'Graduate', 'Graduate',
                    'Non-degree', 'Non-degree', 'Non-degree', 'Non-degree', 'Non-degree'],
    'Ownership': ['Public', 'Public', 'Private non-profit', 'Public', 'Public',
                  'Private for-profit', 'Private for-profit', 'Private for-profit', 'Private for-profit', 'Private for-profit'],
    'Regions': ['South East', 'South East', 'South East', 'South East', 'South East',
                'Far West', 'Plains', 'Great Lakes', 'Far West', 'Far West'],
    'Locales': ['City: Midsize', 'City: Midsize', 'City: Midsize', 'City: Midsize', 'City: Midsize',
                None, None, None, None, None],
    'Locale_Short': ['City', 'City', 'City', 'City', 'City', None, None, None, None, None]
}

# Creating the DataFrame
df = pd.DataFrame(data)


# Create a FacetGrid varying by column and columns ordered with the degree_order variable
g = sns.FacetGrid(df, col="Degree_Type", col_order=['Non-degree','Graduate'])

# Map a scatter plot of Undergrad Population compared to PCTPELL
g.map(plt.scatter, 'OPEID', 'PCTPELL')

plt.show()
plt.clf()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data to create the DataFrame
data = {
    'INSTNM': [
        'Alabama A & M University', 'University of Alabama at Birmingham', 'Amridge University',
        'University of Alabama in Huntsville', 'Alabama State University',
        'SAE Institute of Technology San Francisco', 'Rasmussen College - Overland Park',
        'National Personal Training Institute of Cleveland', 'Bay Area Medical Academy - San Jose Satellite Location',
        'High Desert Medical College'
    ],
    'OPEID': [100200, 105200, 2503400, 105500, 100500, 4205801, 869423, 4220901, 4223701, 4228101],
    'REGION': [5, 5, 5, 5, 5, 8, 4, 3, 8, 8],
    'SAT_AVG_ALL': [850, 1147, None, 1221, 844, None, None, None, None, None],
    'PCTPELL': [0.725, 0.350, 0.746, 0.318, 0.757, None, None, None, None, None],
    'Degree_Type': ['Graduate', 'Graduate', 'Graduate', 'Graduate', 'Graduate',
                    'Non-degree', 'Non-degree', 'Non-degree', 'Non-degree', 'Non-degree'],
    'Ownership': ['Public', 'Public', 'Private non-profit', 'Public', 'Public',
                  'Private for-profit', 'Private for-profit', 'Private for-profit', 'Private for-profit', 'Private for-profit'],
    'Regions': ['South East', 'South East', 'South East', 'South East', 'South East',
                'Far West', 'Plains', 'Great Lakes', 'Far West', 'Far West'],
    'Locales': ['City: Midsize', 'City: Midsize', 'City: Midsize', 'City: Midsize', 'City: Midsize',
                None, None, None, None, None],
    'Locale_Short': ['City', 'City', 'City', 'City', 'City', None, None, None, None, None]
}

# Creating the DataFrame
df = pd.DataFrame(data)



# Re-create the previous plot as an lmplot
sns.lmplot(data=df,
        x='OPEID',
        y='PCTPELL',
        col="Degree_Type",
        col_order=['Non-degree','Graduate'])

plt.show()
plt.clf()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data to create the DataFrame
data = {
    'INSTNM': [
        'Alabama A & M University', 'University of Alabama at Birmingham', 'Amridge University',
        'University of Alabama in Huntsville', 'Alabama State University',
        'SAE Institute of Technology San Francisco', 'Rasmussen College - Overland Park',
        'National Personal Training Institute of Cleveland', 'Bay Area Medical Academy - San Jose Satellite Location',
        'High Desert Medical College'
    ],
    'OPEID': [100200, 105200, 2503400, 105500, 100500, 4205801, 869423, 4220901, 4223701, 4228101],
    'REGION': [5, 5, 5, 5, 5, 8, 4, 3, 8, 8],
    'SAT_AVG_ALL': [850, 1147, None, 1221, 844, None, None, None, None, None],
    'PCTPELL': [0.725, 0.350, 0.746, 0.318, 0.757, None, None, None, None, None],
    'Degree_Type': ['Graduate', 'Graduate', 'Graduate', 'Graduate', 'Graduate',
                    'Non-degree', 'Non-degree', 'Non-degree', 'Non-degree', 'Non-degree'],
    'Ownership': ['Public', 'Public', 'Private non-profit', 'Public', 'Public',
                  'Private for-profit', 'Private for-profit', 'Private for-profit', 'Private for-profit', 'Private for-profit'],
    'Regions': ['South East', 'South East', 'South East', 'South East', 'South East',
                'Far West', 'Plains', 'Great Lakes', 'Far West', 'Far West'],
    'Locales': ['City: Midsize', 'City: Midsize', 'City: Midsize', 'City: Midsize', 'City: Midsize',
                None, None, None, None, None],
    'Locale_Short': ['City', 'City', 'City', 'City', 'City', None, None, None, None, None]
}

# Creating the DataFrame
df = pd.DataFrame(data)

# Create an lmplot that has a column for Ownership, a row for Degree_Type and hue based on the WOMENONLY column
sns.lmplot(data=df,
        x='SAT_AVG_ALL',
        y='Tuition',
        col="Ownership",
        row='Degree_Type',
        row_order=['Graduate', 'Bachelors'],
        hue='WOMENONLY',
)

plt.show()
plt.clf()
