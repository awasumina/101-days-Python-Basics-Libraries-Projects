# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {
    'INSTNM': [
        'Alabama A & M University', 'University of Alabama at Birmingham', 'University of Alabama in Huntsville',
        'Alabama State University', 'The University of Alabama', 'Arizona State University-Polytechnic',
        'Florida Gulf Coast University', 'University of Connecticut-Tri-Campus',
        'University of Connecticut-Avery Point', 'University of Connecticut-Stamford'
    ],
    'OPEID': [
        100200, 105200, 105500, 100500, 105100, 108102, 3255300, 141704, 141705, 141702
    ],
    'REGION': [5, 5, 5, 5, 5, 6, 5, 1, 1, 1],
    'SAT_AVG_ALL': [
        850.0, 1147.0, 1221.0, 844.0, 1181.0, 1143.0, 1081.0, 1233.0, 1233.0, 1233.0
    ],
    'PCTPELL': [0.725, 0.350, 0.318, 0.757, 0.201, 0.383, 0.332, 0.383, 0.285, 0.345],
    'AVGFACSAL': [
        7017.0, 10221.0, 9514.0, 7940.0, 9710.0, 8310.0, 7838.0, 13790.0, 15814.0, 15814.0
    ],
    'COMPL_RPY_5YR_RT': [
        0.477631579, 0.673230442, 0.762222222, 0.43006993, 0.75203252, 0.739734885, 0.76702509,
        0.910939013, 0.910939013, 0.910939013
    ],
    'DEBT_MDN': [
        14600, 14250, 15000, 15274, 17500, 14500, 12000, 18750, 18750, 18750
    ],
    'MEDIAN_HH_INC': [
        49720.22, 55735.22, 58688.62, 46065.20, 57928.41, 69074.33, 62394.85, 80999.86, 80999.86, 80999.86
    ],
    'Tuition': [
        13435.0, 16023.0, 18661.0, 7400.0, 20575.0, 11826.0, 16108.0, 8258.0, 9179.0, 7358.0
    ]
}

# Create the dataframe
df = pd.DataFrame(data)

# Display a regression plot for Tuition
sns.regplot(data=df,
         y='Tuition',
         x='SAT_AVG_ALL',
         marker='^',
         color='g')

plt.show()
plt.clf()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {
    'INSTNM': [
        'Alabama A & M University', 'University of Alabama at Birmingham', 'University of Alabama in Huntsville',
        'Alabama State University', 'The University of Alabama', 'Arizona State University-Polytechnic',
        'Florida Gulf Coast University', 'University of Connecticut-Tri-Campus',
        'University of Connecticut-Avery Point', 'University of Connecticut-Stamford'
    ],
    'OPEID': [
        100200, 105200, 105500, 100500, 105100, 108102, 3255300, 141704, 141705, 141702
    ],
    'REGION': [5, 5, 5, 5, 5, 6, 5, 1, 1, 1],
    'SAT_AVG_ALL': [
        850.0, 1147.0, 1221.0, 844.0, 1181.0, 1143.0, 1081.0, 1233.0, 1233.0, 1233.0
    ],
    'PCTPELL': [0.725, 0.350, 0.318, 0.757, 0.201, 0.383, 0.332, 0.383, 0.285, 0.345],
    'AVGFACSAL': [
        7017.0, 10221.0, 9514.0, 7940.0, 9710.0, 8310.0, 7838.0, 13790.0, 15814.0, 15814.0
    ],
    'COMPL_RPY_5YR_RT': [
        0.477631579, 0.673230442, 0.762222222, 0.43006993, 0.75203252, 0.739734885, 0.76702509,
        0.910939013, 0.910939013, 0.910939013
    ],
    'DEBT_MDN': [
        14600, 14250, 15000, 15274, 17500, 14500, 12000, 18750, 18750, 18750
    ],
    'MEDIAN_HH_INC': [
        49720.22, 55735.22, 58688.62, 46065.20, 57928.41, 69074.33, 62394.85, 80999.86, 80999.86, 80999.86
    ],
    'Tuition': [
        13435.0, 16023.0, 18661.0, 7400.0, 20575.0, 11826.0, 16108.0, 8258.0, 9179.0, 7358.0
    ]
}

# Create the dataframe
df = pd.DataFrame(data)

# Display the residual plot
sns.residplot(data=df,
          y='Tuition',
          x='SAT_AVG_ALL',
          color='g')

plt.show()
plt.clf()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {
    'INSTNM': [
        'Alabama A & M University', 'University of Alabama at Birmingham', 'University of Alabama in Huntsville',
        'Alabama State University', 'The University of Alabama', 'Arizona State University-Polytechnic',
        'Florida Gulf Coast University', 'University of Connecticut-Tri-Campus',
        'University of Connecticut-Avery Point', 'University of Connecticut-Stamford'
    ],
    'OPEID': [
        100200, 105200, 105500, 100500, 105100, 108102, 3255300, 141704, 141705, 141702
    ],
    'REGION': [5, 5, 5, 5, 5, 6, 5, 1, 1, 1],
    'SAT_AVG_ALL': [
        850.0, 1147.0, 1221.0, 844.0, 1181.0, 1143.0, 1081.0, 1233.0, 1233.0, 1233.0
    ],
    'PCTPELL': [0.725, 0.350, 0.318, 0.757, 0.201, 0.383, 0.332, 0.383, 0.285, 0.345],
    'AVGFACSAL': [
        7017.0, 10221.0, 9514.0, 7940.0, 9710.0, 8310.0, 7838.0, 13790.0, 15814.0, 15814.0
    ],
    'COMPL_RPY_5YR_RT': [
        0.477631579, 0.673230442, 0.762222222, 0.43006993, 0.75203252, 0.739734885, 0.76702509,
        0.910939013, 0.910939013, 0.910939013
    ],
    'DEBT_MDN': [
        14600, 14250, 15000, 15274, 17500, 14500, 12000, 18750, 18750, 18750
    ],
    'MEDIAN_HH_INC': [
        49720.22, 55735.22, 58688.62, 46065.20, 57928.41, 69074.33, 62394.85, 80999.86, 80999.86, 80999.86
    ],
    'Tuition': [
        13435.0, 16023.0, 18661.0, 7400.0, 20575.0, 11826.0, 16108.0, 8258.0, 9179.0, 7358.0
    ]
}

# Create the dataframe
df = pd.DataFrame(data)

# Plot a regression plot of Tuition and the Percentage of Pell Grants
sns.regplot(data=df,
            y='Tuition',
            x='PCTPELL')

plt.show()
plt.clf()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {
    'INSTNM': [
        'Alabama A & M University', 'University of Alabama at Birmingham', 'University of Alabama in Huntsville',
        'Alabama State University', 'The University of Alabama', 'Arizona State University-Polytechnic',
        'Florida Gulf Coast University', 'University of Connecticut-Tri-Campus',
        'University of Connecticut-Avery Point', 'University of Connecticut-Stamford'
    ],
    'OPEID': [
        100200, 105200, 105500, 100500, 105100, 108102, 3255300, 141704, 141705, 141702
    ],
    'REGION': [5, 5, 5, 5, 5, 6, 5, 1, 1, 1],
    'SAT_AVG_ALL': [
        850.0, 1147.0, 1221.0, 844.0, 1181.0, 1143.0, 1081.0, 1233.0, 1233.0, 1233.0
    ],
    'PCTPELL': [0.725, 0.350, 0.318, 0.757, 0.201, 0.383, 0.332, 0.383, 0.285, 0.345],
    'AVGFACSAL': [
        7017.0, 10221.0, 9514.0, 7940.0, 9710.0, 8310.0, 7838.0, 13790.0, 15814.0, 15814.0
    ],
    'COMPL_RPY_5YR_RT': [
        0.477631579, 0.673230442, 0.762222222, 0.43006993, 0.75203252, 0.739734885, 0.76702509,
        0.910939013, 0.910939013, 0.910939013
    ],
    'DEBT_MDN': [
        14600, 14250, 15000, 15274, 17500, 14500, 12000, 18750, 18750, 18750
    ],
    'MEDIAN_HH_INC': [
        49720.22, 55735.22, 58688.62, 46065.20, 57928.41, 69074.33, 62394.85, 80999.86, 80999.86, 80999.86
    ],
    'Tuition': [
        13435.0, 16023.0, 18661.0, 7400.0, 20575.0, 11826.0, 16108.0, 8258.0, 9179.0, 7358.0
    ]
}

# Create the dataframe
df = pd.DataFrame(data)

# Create another plot that estimates the tuition by PCTPELL
sns.regplot(data=df,
            y='Tuition',
            x='PCTPELL',
            x_bins=5)

plt.show()
plt.clf()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {
    'INSTNM': [
        'Alabama A & M University', 'University of Alabama at Birmingham', 'University of Alabama in Huntsville',
        'Alabama State University', 'The University of Alabama', 'Arizona State University-Polytechnic',
        'Florida Gulf Coast University', 'University of Connecticut-Tri-Campus',
        'University of Connecticut-Avery Point', 'University of Connecticut-Stamford'
    ],
    'OPEID': [
        100200, 105200, 105500, 100500, 105100, 108102, 3255300, 141704, 141705, 141702
    ],
    'REGION': [5, 5, 5, 5, 5, 6, 5, 1, 1, 1],
    'SAT_AVG_ALL': [
        850.0, 1147.0, 1221.0, 844.0, 1181.0, 1143.0, 1081.0, 1233.0, 1233.0, 1233.0
    ],
    'PCTPELL': [0.725, 0.350, 0.318, 0.757, 0.201, 0.383, 0.332, 0.383, 0.285, 0.345],
    'AVGFACSAL': [
        7017.0, 10221.0, 9514.0, 7940.0, 9710.0, 8310.0, 7838.0, 13790.0, 15814.0, 15814.0
    ],
    'COMPL_RPY_5YR_RT': [
        0.477631579, 0.673230442, 0.762222222, 0.43006993, 0.75203252, 0.739734885, 0.76702509,
        0.910939013, 0.910939013, 0.910939013
    ],
    'DEBT_MDN': [
        14600, 14250, 15000, 15274, 17500, 14500, 12000, 18750, 18750, 18750
    ],
    'MEDIAN_HH_INC': [
        49720.22, 55735.22, 58688.62, 46065.20, 57928.41, 69074.33, 62394.85, 80999.86, 80999.86, 80999.86
    ],
    'Tuition': [
        13435.0, 16023.0, 18661.0, 7400.0, 20575.0, 11826.0, 16108.0, 8258.0, 9179.0, 7358.0
    ]
}

# Create the dataframe
df = pd.DataFrame(data)


# Create another plot that estimates the tuition by PCTPELL
sns.regplot(data=df,
            y='Tuition',
            x='PCTPELL',
            x_bins=5)

plt.show()
plt.clf()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {
    'INSTNM': [
        'Alabama A & M University', 'University of Alabama at Birmingham', 'University of Alabama in Huntsville',
        'Alabama State University', 'The University of Alabama', 'Arizona State University-Polytechnic',
        'Florida Gulf Coast University', 'University of Connecticut-Tri-Campus',
        'University of Connecticut-Avery Point', 'University of Connecticut-Stamford'
    ],
    'OPEID': [
        100200, 105200, 105500, 100500, 105100, 108102, 3255300, 141704, 141705, 141702
    ],
    'REGION': [5, 5, 5, 5, 5, 6, 5, 1, 1, 1],
    'SAT_AVG_ALL': [
        850.0, 1147.0, 1221.0, 844.0, 1181.0, 1143.0, 1081.0, 1233.0, 1233.0, 1233.0
    ],
    'PCTPELL': [0.725, 0.350, 0.318, 0.757, 0.201, 0.383, 0.332, 0.383, 0.285, 0.345],
    'AVGFACSAL': [
        7017.0, 10221.0, 9514.0, 7940.0, 9710.0, 8310.0, 7838.0, 13790.0, 15814.0, 15814.0
    ],
    'COMPL_RPY_5YR_RT': [
        0.477631579, 0.673230442, 0.762222222, 0.43006993, 0.75203252, 0.739734885, 0.76702509,
        0.910939013, 0.910939013, 0.910939013
    ],
    'DEBT_MDN': [
        14600, 14250, 15000, 15274, 17500, 14500, 12000, 18750, 18750, 18750
    ],
    'MEDIAN_HH_INC': [
        49720.22, 55735.22, 58688.62, 46065.20, 57928.41, 69074.33, 62394.85, 80999.86, 80999.86, 80999.86
    ],
    'Tuition': [
        13435.0, 16023.0, 18661.0, 7400.0, 20575.0, 11826.0, 16108.0, 8258.0, 9179.0, 7358.0
    ]
}

# Create the dataframe
df = pd.DataFrame(data)


# Create a scatter plot and bin the data into 5 bins
sns.regplot(data=df,
            y='Tuition',
            x='PCTPELL',
            x_bins=5)

plt.show()
plt.clf()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {
    'INSTNM': [
        'Alabama A & M University', 'University of Alabama at Birmingham', 'University of Alabama in Huntsville',
        'Alabama State University', 'The University of Alabama', 'Arizona State University-Polytechnic',
        'Florida Gulf Coast University', 'University of Connecticut-Tri-Campus',
        'University of Connecticut-Avery Point', 'University of Connecticut-Stamford'
    ],
    'OPEID': [
        100200, 105200, 105500, 100500, 105100, 108102, 3255300, 141704, 141705, 141702
    ],
    'REGION': [5, 5, 5, 5, 5, 6, 5, 1, 1, 1],
    'SAT_AVG_ALL': [
        850.0, 1147.0, 1221.0, 844.0, 1181.0, 1143.0, 1081.0, 1233.0, 1233.0, 1233.0
    ],    
    'PCTPELL': [0.725, 0.350, 0.318, 0.757, 0.201, 0.383, 0.332, 0.383, 0.285, 0.345],
    'AVGFACSAL': [
        7017.0, 10221.0, 9514.0, 7940.0, 9710.0, 8310.0, 7838.0, 13790.0, 15814.0, 15814.0
    ],
    'COMPL_RPY_5YR_RT': [
        0.477631579, 0.673230442, 0.762222222, 0.43006993, 0.75203252, 0.739734885, 0.76702509,
        0.910939013, 0.910939013, 0.910939013
    ],
    'DEBT_MDN': [
        14600, 14250, 15000, 15274, 17500, 14500, 12000, 18750, 18750, 18750
    ],
    'MEDIAN_HH_INC': [
        49720.22, 55735.22, 58688.62, 46065.20, 57928.41, 69074.33, 62394.85, 80999.86, 80999.86, 80999.86
    ],
    'Tuition': [
        13435.0, 16023.0, 18661.0, 7400.0, 20575.0, 11826.0, 16108.0, 8258.0, 9179.0, 7358.0
    ]
}

# Create the dataframe
df = pd.DataFrame(data)

# Create a scatter plot by disabling the regression line
sns.regplot(data=df,
            y='Tuition',
            x='PCTPELL',
            fit_reg=False)

plt.show()
plt.clf()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {
    'INSTNM': [
        'Alabama A & M University', 'University of Alabama at Birmingham', 'University of Alabama in Huntsville',
        'Alabama State University', 'The University of Alabama', 'Arizona State University-Polytechnic',
        'Florida Gulf Coast University', 'University of Connecticut-Tri-Campus',
        'University of Connecticut-Avery Point', 'University of Connecticut-Stamford'
    ],
    'OPEID': [
        100200, 105200, 105500, 100500, 105100, 108102, 3255300, 141704, 141705, 141702
    ],
    'REGION': [5, 5, 5, 5, 5, 6, 5, 1, 1, 1],
    'SAT_AVG_ALL': [
        850.0, 1147.0, 1221.0, 844.0, 1181.0, 1143.0, 1081.0, 1233.0, 1233.0, 1233.0
    ],
    'PCTPELL': [0.725, 0.350, 0.318, 0.757, 0.201, 0.383, 0.332, 0.383, 0.285, 0.345],
    'AVGFACSAL': [
        7017.0, 10221.0, 9514.0, 7940.0, 9710.0, 8310.0, 7838.0, 13790.0, 15814.0, 15814.0
    ],
    'COMPL_RPY_5YR_RT': [
        0.477631579, 0.673230442, 0.762222222, 0.43006993, 0.75203252, 0.739734885, 0.76702509,
        0.910939013, 0.910939013, 0.910939013
    ],
    'DEBT_MDN': [
        14600, 14250, 15000, 15274, 17500, 14500, 12000, 18750, 18750, 18750
    ],
    'MEDIAN_HH_INC': [
        49720.22, 55735.22, 58688.62, 46065.20, 57928.41, 69074.33, 62394.85, 80999.86, 80999.86, 80999.86
    ],
    'Tuition': [
        13435.0, 16023.0, 18661.0, 7400.0, 20575.0, 11826.0, 16108.0, 8258.0, 9179.0, 7358.0
    ]
}

# Create the dataframe
df = pd.DataFrame(data)


# Create a regplot and bin the data into 8 bins
sns.regplot(data=df,
         y='Tuition',
         x='PCTPELL',
         x_bins=8)

plt.show()   
plt.clf()
