# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'school': ['GP', 'GP', 'GP', 'GP', 'GP', 'MS', 'MS', 'MS', 'MS', 'MS'],
    'sex': ['F', 'F', 'F', 'F', 'F', 'M', 'M', 'M', 'M', 'M'],
    'age': [18, 17, 15, 15, 16, 20, 17, 21, 18, 19],
    'famsize': ['GT3', 'GT3', 'LE3', 'GT3', 'GT3', 'LE3', 'LE3', 'GT3', 'LE3', 'LE3'],
    'Pstatus': ['A', 'T', 'T', 'T', 'T', 'A', 'T', 'T', 'T', 'T'],
    'G1': [5, 5, 7, 15, 6, 9, 14, 10, 11, 8],
    'G2': [6, 5, 8, 14, 10, 9, 16, 8, 12, 9],
    'G3': [6, 6, 10, 15, 10, 9, 16, 7, 10, 9],
    'location': ['Urban', 'Urban', 'Urban', 'Urban', 'Urban', 'Urban', 'Urban', 'Rural', 'Rural', 'Urban'],
    'study_time': ['2 to 5 hours', '2 to 5 hours', '2 to 5 hours', '5 to 10 hours', '2 to 5 hours', '2 to 5 hours', '<2 hours', '<2 hours', '<2 hours', '<2 hours']
}

student_data = pd.DataFrame(data)

# Specify the category ordering
study_time_order = ["<2 hours", "2 to 5 hours",
                    "5 to 10 hours", ">10 hours"]

# Create a box plot and set the order of the categories


sns.catplot(x="study_time", y="G3",
            data=student_data,
            kind="box",order=study_time_order)




# Show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'school': ['GP', 'GP', 'GP', 'GP', 'GP', 'MS', 'MS', 'MS', 'MS', 'MS'],
    'sex': ['F', 'F', 'F', 'F', 'F', 'M', 'M', 'M', 'M', 'M'],
    'age': [18, 17, 15, 15, 16, 20, 17, 21, 18, 19],
    'famsize': ['GT3', 'GT3', 'LE3', 'GT3', 'GT3', 'LE3', 'LE3', 'GT3', 'LE3', 'LE3'],
    'Pstatus': ['A', 'T', 'T', 'T', 'T', 'A', 'T', 'T', 'T', 'T'],
    'G1': [5, 5, 7, 15, 6, 9, 14, 10, 11, 8],
    'G2': [6, 5, 8, 14, 10, 9, 16, 8, 12, 9],
    'G3': [6, 6, 10, 15, 10, 9, 16, 7, 10, 9],
    'location': ['Urban', 'Urban', 'Urban', 'Urban', 'Urban', 'Urban', 'Urban', 'Rural', 'Rural', 'Urban'],
    'study_time': ['2 to 5 hours', '2 to 5 hours', '2 to 5 hours', '5 to 10 hours', '2 to 5 hours', '2 to 5 hours', '<2 hours', '<2 hours', '<2 hours', '<2 hours']
}

student_data = pd.DataFrame(data)



# Create a box plot with subgroups and omit the outliers
sns.catplot(x="study_time", y="G3",
            data=student_data,
            kind="box",col="location",hue="location",showfliers =False)


# Show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'school': ['GP', 'GP', 'GP', 'GP', 'GP', 'MS', 'MS', 'MS', 'MS', 'MS'],
    'sex': ['F', 'F', 'F', 'F', 'F', 'M', 'M', 'M', 'M', 'M'],
    'age': [18, 17, 15, 15, 16, 20, 17, 21, 18, 19],
    'famsize': ['GT3', 'GT3', 'LE3', 'GT3', 'GT3', 'LE3', 'LE3', 'GT3', 'LE3', 'LE3'],
    'Pstatus': ['A', 'T', 'T', 'T', 'T', 'A', 'T', 'T', 'T', 'T'],
    'G1': [5, 5, 7, 15, 6, 9, 14, 10, 11, 8],
    'G2': [6, 5, 8, 14, 10, 9, 16, 8, 12, 9],
    'G3': [6, 6, 10, 15, 10, 9, 16, 7, 10, 9],
    'location': ['Urban', 'Urban', 'Urban', 'Urban', 'Urban', 'Urban', 'Urban', 'Rural', 'Rural', 'Urban'],
    'study_time': ['2 to 5 hours', '2 to 5 hours', '2 to 5 hours', '5 to 10 hours', '2 to 5 hours', '2 to 5 hours', '<2 hours', '<2 hours', '<2 hours', '<2 hours']
}

student_data = pd.DataFrame(data)

# Extend the whiskers to the 5th and 95th percentile
sns.catplot(x="age", y="G3",
            data=student_data,
            kind="box",
            whis=0.5)

# Show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'school': ['GP', 'GP', 'GP', 'GP', 'GP', 'MS', 'MS', 'MS', 'MS', 'MS'],
    'sex': ['F', 'F', 'F', 'F', 'F', 'M', 'M', 'M', 'M', 'M'],
    'age': [18, 17, 15, 15, 16, 20, 17, 21, 18, 19],
    'famsize': ['GT3', 'GT3', 'LE3', 'GT3', 'GT3', 'LE3', 'LE3', 'GT3', 'LE3', 'LE3'],
    'Pstatus': ['A', 'T', 'T', 'T', 'T', 'A', 'T', 'T', 'T', 'T'],
    'G1': [5, 5, 7, 15, 6, 9, 14, 10, 11, 8],
    'G2': [6, 5, 8, 14, 10, 9, 16, 8, 12, 9],
    'G3': [6, 6, 10, 15, 10, 9, 16, 7, 10, 9],
    'location': ['Urban', 'Urban', 'Urban', 'Urban', 'Urban', 'Urban', 'Urban', 'Rural', 'Rural', 'Urban'],
    'study_time': ['2 to 5 hours', '2 to 5 hours', '2 to 5 hours', '5 to 10 hours', '2 to 5 hours', '2 to 5 hours', '<2 hours', '<2 hours', '<2 hours', '<2 hours']
}

student_data = pd.DataFrame(data)

# Set the whiskers at the min and max values
sns.catplot(x="age", y="G3",
            data=student_data,
            kind="box",
            whis=[5, 95])

# Show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'school': ['GP', 'GP', 'GP', 'GP', 'GP', 'MS', 'MS', 'MS', 'MS', 'MS'],
    'sex': ['F', 'F', 'F', 'F', 'F', 'M', 'M', 'M', 'M', 'M'],
    'age': [18, 17, 15, 15, 16, 20, 17, 21, 18, 19],
    'famsize': ['GT3', 'GT3', 'LE3', 'GT3', 'GT3', 'LE3', 'LE3', 'GT3', 'LE3', 'LE3'],
    'Pstatus': ['A', 'T', 'T', 'T', 'T', 'A', 'T', 'T', 'T', 'T'],
    'G1': [5, 5, 7, 15, 6, 9, 14, 10, 11, 8],
    'G2': [6, 5, 8, 14, 10, 9, 16, 8, 12, 9],
    'G3': [6, 6, 10, 15, 10, 9, 16, 7, 10, 9],
    'location': ['Urban', 'Urban', 'Urban', 'Urban', 'Urban', 'Urban', 'Urban', 'Rural', 'Rural', 'Urban'],
    'study_time': ['2 to 5 hours', '2 to 5 hours', '2 to 5 hours', '5 to 10 hours', '2 to 5 hours', '2 to 5 hours', '<2 hours', '<2 hours', '<2 hours', '<2 hours']
}

student_data = pd.DataFrame(data)

# Set the whiskers at the min and max values
sns.catplot(x="age", y="G3",
            data=student_data,
            kind="box",
            whis=[0, 100])

# Show plot
plt.show()
