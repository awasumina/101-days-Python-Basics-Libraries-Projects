# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'Unnamed: 0': [0, 1, 2, 3, 4, 826, 827, 828, 829, 830],
    'School Name': [
        'HOGARTH KINGEEKUK MEMORIAL SCHOOL', 'AKIACHAK SCHOOL', 'GAMBELL SCHOOL', 'BURCHELL HIGH SCHOOL',
        'AKIAK SCHOOL', 'MOUNT HOPE HIGH SCHOOL', 'GEARY ELEMENTARY SCHOOL', 'TRIUMPH HIGH SCHOOL',
        'HEM JUNIOR/SENIOR HIGH SCHOOL', 'ROOSEVELT HIGH SCHOOL'
    ],
    'City': ['SAVOONGA', 'AKIACHAK', 'GAMBELL', 'WASILLA', 'AKIAK', 'MOUNT HOPE', 'LEFT HAND', 'CHEYENNE', 'HANNA', 'CASPER'],
    'State': ['AK', 'AK', 'AK', 'AK', 'AK', 'WV', 'WV', 'WY', 'WY', 'WY'],
    'District Name': [
        'BERING STRAIT SCHOOL DISTRICT', 'YUPIIT SCHOOL DISTRICT', 'BERING STRAIT SCHOOL DISTRICT',
        'MATANUSKA-SUSITNA BOROUGH SCHOOL DISTRICT', 'YUPIIT SCHOOL DISTRICT', 'FAYETTE COUNTY SCHOOLS',
        'ROANE COUNTY SCHOOLS', 'LARAMIE COUNTY SCHOOL DISTRICT #1', 'CARBON COUNTY SCHOOL DISTRICT #2',
        'NATRONA COUNTY SCHOOL DISTRICT #1'
    ],
    'Model Selected': ['Transformation']*10,
    'Award_Amount': [471014, 520579, 449592, 641184, 399686, 342189, 260000, 297300, 274000, 431382],
    'Region': ['West', 'West', 'West', 'West', 'West', 'South', 'South', 'West', 'West', 'West']
}

# Create the dataframe
df = pd.DataFrame(data)

# Create the stripplot
sns.stripplot(data=df,
         x='Award_Amount',
         y='Model Selected',
         jitter=True)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'Unnamed: 0': [0, 1, 2, 3, 4, 826, 827, 828, 829, 830],
    'School Name': [
        'HOGARTH KINGEEKUK MEMORIAL SCHOOL', 'AKIACHAK SCHOOL', 'GAMBELL SCHOOL', 'BURCHELL HIGH SCHOOL',
        'AKIAK SCHOOL', 'MOUNT HOPE HIGH SCHOOL', 'GEARY ELEMENTARY SCHOOL', 'TRIUMPH HIGH SCHOOL',
        'HEM JUNIOR/SENIOR HIGH SCHOOL', 'ROOSEVELT HIGH SCHOOL'
    ],
    'City': ['SAVOONGA', 'AKIACHAK', 'GAMBELL', 'WASILLA', 'AKIAK', 'MOUNT HOPE', 'LEFT HAND', 'CHEYENNE', 'HANNA', 'CASPER'],
    'State': ['AK', 'AK', 'AK', 'AK', 'AK', 'WV', 'WV', 'WY', 'WY', 'WY'],
    'District Name': [
        'BERING STRAIT SCHOOL DISTRICT', 'YUPIIT SCHOOL DISTRICT', 'BERING STRAIT SCHOOL DISTRICT',
        'MATANUSKA-SUSITNA BOROUGH SCHOOL DISTRICT', 'YUPIIT SCHOOL DISTRICT', 'FAYETTE COUNTY SCHOOLS',
        'ROANE COUNTY SCHOOLS', 'LARAMIE COUNTY SCHOOL DISTRICT #1', 'CARBON COUNTY SCHOOL DISTRICT #2',
        'NATRONA COUNTY SCHOOL DISTRICT #1'
    ],
    'Model Selected': ['Transformation']*10,
    'Award_Amount': [471014, 520579, 449592, 641184, 399686, 342189, 260000, 297300, 274000, 431382],
    'Region': ['West', 'West', 'West', 'West', 'West', 'South', 'South', 'West', 'West', 'West']
}

# Create the dataframe
df = pd.DataFrame(data)

# Create and display a swarmplot with hue set to the Region
sns.swarmplot(data=df,
         x='Award_Amount',
         y='Model Selected',
         hue='Region')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'Unnamed: 0': [0, 1, 2, 3, 4, 826, 827, 828, 829, 830],
    'School Name': [
        'HOGARTH KINGEEKUK MEMORIAL SCHOOL', 'AKIACHAK SCHOOL', 'GAMBELL SCHOOL', 'BURCHELL HIGH SCHOOL',
        'AKIAK SCHOOL', 'MOUNT HOPE HIGH SCHOOL', 'GEARY ELEMENTARY SCHOOL', 'TRIUMPH HIGH SCHOOL',
        'HEM JUNIOR/SENIOR HIGH SCHOOL', 'ROOSEVELT HIGH SCHOOL'
    ],
    'City': ['SAVOONGA', 'AKIACHAK', 'GAMBELL', 'WASILLA', 'AKIAK', 'MOUNT HOPE', 'LEFT HAND', 'CHEYENNE', 'HANNA', 'CASPER'],
    'State': ['AK', 'AK', 'AK', 'AK', 'AK', 'WV', 'WV', 'WY', 'WY', 'WY'],
    'District Name': [
        'BERING STRAIT SCHOOL DISTRICT', 'YUPIIT SCHOOL DISTRICT', 'BERING STRAIT SCHOOL DISTRICT',
        'MATANUSKA-SUSITNA BOROUGH SCHOOL DISTRICT', 'YUPIIT SCHOOL DISTRICT', 'FAYETTE COUNTY SCHOOLS',
        'ROANE COUNTY SCHOOLS', 'LARAMIE COUNTY SCHOOL DISTRICT #1', 'CARBON COUNTY SCHOOL DISTRICT #2',
        'NATRONA COUNTY SCHOOL DISTRICT #1'
    ],
    'Model Selected': ['Transformation']*10,
    'Award_Amount': [471014, 520579, 449592, 641184, 399686, 342189, 260000, 297300, 274000, 431382],
    'Region': ['West', 'West', 'West', 'West', 'West', 'South', 'South', 'West', 'West', 'West']
}

# Create the dataframe
df = pd.DataFrame(data)

# Create a boxplot
sns.boxplot(data=df,
         x='Award_Amount',
         y='Model Selected',)

plt.show()
plt.clf()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'Unnamed: 0': [0, 1, 2, 3, 4, 826, 827, 828, 829, 830],
    'School Name': [
        'HOGARTH KINGEEKUK MEMORIAL SCHOOL', 'AKIACHAK SCHOOL', 'GAMBELL SCHOOL', 'BURCHELL HIGH SCHOOL',
        'AKIAK SCHOOL', 'MOUNT HOPE HIGH SCHOOL', 'GEARY ELEMENTARY SCHOOL', 'TRIUMPH HIGH SCHOOL',
        'HEM JUNIOR/SENIOR HIGH SCHOOL', 'ROOSEVELT HIGH SCHOOL'
    ],
    'City': ['SAVOONGA', 'AKIACHAK', 'GAMBELL', 'WASILLA', 'AKIAK', 'MOUNT HOPE', 'LEFT HAND', 'CHEYENNE', 'HANNA', 'CASPER'],
    'State': ['AK', 'AK', 'AK', 'AK', 'AK', 'WV', 'WV', 'WY', 'WY', 'WY'],
    'District Name': [
        'BERING STRAIT SCHOOL DISTRICT', 'YUPIIT SCHOOL DISTRICT', 'BERING STRAIT SCHOOL DISTRICT',
        'MATANUSKA-SUSITNA BOROUGH SCHOOL DISTRICT', 'YUPIIT SCHOOL DISTRICT', 'FAYETTE COUNTY SCHOOLS',
        'ROANE COUNTY SCHOOLS', 'LARAMIE COUNTY SCHOOL DISTRICT #1', 'CARBON COUNTY SCHOOL DISTRICT #2',
        'NATRONA COUNTY SCHOOL DISTRICT #1'
    ],
    'Model Selected': ['Transformation']*10,
    'Award_Amount': [471014, 520579, 449592, 641184, 399686, 342189, 260000, 297300, 274000, 431382],
    'Region': ['West', 'West', 'West', 'West', 'West', 'South', 'South', 'West', 'West', 'West']
}

# Create the dataframe
df = pd.DataFrame(data)

# Create a violinplot with the husl palette
sns.violinplot(data=df,
         x='Award_Amount',
         y='Model Selected',
         palette='husl')

plt.show()
plt.clf()
# Out:
# <ipython-input-4-63816e1799a2>:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df,

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'Unnamed: 0': [0, 1, 2, 3, 4, 826, 827, 828, 829, 830],
    'School Name': [
        'HOGARTH KINGEEKUK MEMORIAL SCHOOL', 'AKIACHAK SCHOOL', 'GAMBELL SCHOOL', 'BURCHELL HIGH SCHOOL',
        'AKIAK SCHOOL', 'MOUNT HOPE HIGH SCHOOL', 'GEARY ELEMENTARY SCHOOL', 'TRIUMPH HIGH SCHOOL',
        'HEM JUNIOR/SENIOR HIGH SCHOOL', 'ROOSEVELT HIGH SCHOOL'
    ],
    'City': ['SAVOONGA', 'AKIACHAK', 'GAMBELL', 'WASILLA', 'AKIAK', 'MOUNT HOPE', 'LEFT HAND', 'CHEYENNE', 'HANNA', 'CASPER'],
    'State': ['AK', 'AK', 'AK', 'AK', 'AK', 'WV', 'WV', 'WY', 'WY', 'WY'],
    'District Name': [
        'BERING STRAIT SCHOOL DISTRICT', 'YUPIIT SCHOOL DISTRICT', 'BERING STRAIT SCHOOL DISTRICT',
        'MATANUSKA-SUSITNA BOROUGH SCHOOL DISTRICT', 'YUPIIT SCHOOL DISTRICT', 'FAYETTE COUNTY SCHOOLS',
        'ROANE COUNTY SCHOOLS', 'LARAMIE COUNTY SCHOOL DISTRICT #1', 'CARBON COUNTY SCHOOL DISTRICT #2',
        'NATRONA COUNTY SCHOOL DISTRICT #1'
    ],
    'Model Selected': ['Transformation']*10,
    'Award_Amount': [471014, 520579, 449592, 641184, 399686, 342189, 260000, 297300, 274000, 431382],
    'Region': ['West', 'West', 'West', 'West', 'West', 'South', 'South', 'West', 'West', 'West']
}

# Create the dataframe
df = pd.DataFrame(data)

# Create a boxenplot with the Paired palette and the Region column as the hue
sns.boxenplot(data=df,
         x='Award_Amount',
         y='Model Selected',
         palette='Paired',
         hue='Region')

plt.show()
plt.clf()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'Unnamed: 0': [0, 1, 2, 3, 4, 826, 827, 828, 829, 830],
    'School Name': [
        'HOGARTH KINGEEKUK MEMORIAL SCHOOL', 'AKIACHAK SCHOOL', 'GAMBELL SCHOOL', 'BURCHELL HIGH SCHOOL',
        'AKIAK SCHOOL', 'MOUNT HOPE HIGH SCHOOL', 'GEARY ELEMENTARY SCHOOL', 'TRIUMPH HIGH SCHOOL',
        'HEM JUNIOR/SENIOR HIGH SCHOOL', 'ROOSEVELT HIGH SCHOOL'
    ],
    'City': ['SAVOONGA', 'AKIACHAK', 'GAMBELL', 'WASILLA', 'AKIAK', 'MOUNT HOPE', 'LEFT HAND', 'CHEYENNE', 'HANNA', 'CASPER'],
    'State': ['AK', 'AK', 'AK', 'AK', 'AK', 'WV', 'WV', 'WY', 'WY', 'WY'],
    'District Name': [
        'BERING STRAIT SCHOOL DISTRICT', 'YUPIIT SCHOOL DISTRICT', 'BERING STRAIT SCHOOL DISTRICT',
        'MATANUSKA-SUSITNA BOROUGH SCHOOL DISTRICT', 'YUPIIT SCHOOL DISTRICT', 'FAYETTE COUNTY SCHOOLS',
        'ROANE COUNTY SCHOOLS', 'LARAMIE COUNTY SCHOOL DISTRICT #1', 'CARBON COUNTY SCHOOL DISTRICT #2',
        'NATRONA COUNTY SCHOOL DISTRICT #1'
    ],
    'Model Selected': ['Transformation']*10,
    'Award_Amount': [471014, 520579, 449592, 641184, 399686, 342189, 260000, 297300, 274000, 431382],
    'Region': ['West', 'West', 'West', 'West', 'West', 'South', 'South', 'West', 'West', 'West']
}

# Create the dataframe
df = pd.DataFrame(data)

# Show a countplot with the number of models used with each region a different color
sns.countplot(data=df,
         y="Model Selected",
         hue="Region")

plt.show()
plt.clf()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'Unnamed: 0': [0, 1, 2, 3, 4, 826, 827, 828, 829, 830],
    'School Name': [
        'HOGARTH KINGEEKUK MEMORIAL SCHOOL', 'AKIACHAK SCHOOL', 'GAMBELL SCHOOL', 'BURCHELL HIGH SCHOOL',
        'AKIAK SCHOOL', 'MOUNT HOPE HIGH SCHOOL', 'GEARY ELEMENTARY SCHOOL', 'TRIUMPH HIGH SCHOOL',
        'HEM JUNIOR/SENIOR HIGH SCHOOL', 'ROOSEVELT HIGH SCHOOL'
    ],
    'City': ['SAVOONGA', 'AKIACHAK', 'GAMBELL', 'WASILLA', 'AKIAK', 'MOUNT HOPE', 'LEFT HAND', 'CHEYENNE', 'HANNA', 'CASPER'],
    'State': ['AK', 'AK', 'AK', 'AK', 'AK', 'WV', 'WV', 'WY', 'WY', 'WY'],
    'District Name': [
        'BERING STRAIT SCHOOL DISTRICT', 'YUPIIT SCHOOL DISTRICT', 'BERING STRAIT SCHOOL DISTRICT',
        'MATANUSKA-SUSITNA BOROUGH SCHOOL DISTRICT', 'YUPIIT SCHOOL DISTRICT', 'FAYETTE COUNTY SCHOOLS',
        'ROANE COUNTY SCHOOLS', 'LARAMIE COUNTY SCHOOL DISTRICT #1', 'CARBON COUNTY SCHOOL DISTRICT #2',
        'NATRONA COUNTY SCHOOL DISTRICT #1'
    ],
    'Model Selected': ['Transformation']*10,
    'Award_Amount': [471014, 520579, 449592, 641184, 399686, 342189, 260000, 297300, 274000, 431382],
    'Region': ['West', 'West', 'West', 'West', 'West', 'South', 'South', 'West', 'West', 'West']
}

# Create the dataframe
df = pd.DataFrame(data)

# Create a pointplot and include the capsize in order to show caps on the error bars
sns.pointplot(data=df,
         y='Award_Amount',
         x='Model Selected',
         capsize=.1)

plt.show()  
plt.clf()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'Unnamed: 0': [0, 1, 2, 3, 4, 826, 827, 828, 829, 830],
    'School Name': [
        'HOGARTH KINGEEKUK MEMORIAL SCHOOL', 'AKIACHAK SCHOOL', 'GAMBELL SCHOOL', 'BURCHELL HIGH SCHOOL',
        'AKIAK SCHOOL', 'MOUNT HOPE HIGH SCHOOL', 'GEARY ELEMENTARY SCHOOL', 'TRIUMPH HIGH SCHOOL',
        'HEM JUNIOR/SENIOR HIGH SCHOOL', 'ROOSEVELT HIGH SCHOOL'
    ],
    'City': ['SAVOONGA', 'AKIACHAK', 'GAMBELL', 'WASILLA', 'AKIAK', 'MOUNT HOPE', 'LEFT HAND', 'CHEYENNE', 'HANNA', 'CASPER'],
    'State': ['AK', 'AK', 'AK', 'AK', 'AK', 'WV', 'WV', 'WY', 'WY', 'WY'],
    'District Name': [
        'BERING STRAIT SCHOOL DISTRICT', 'YUPIIT SCHOOL DISTRICT', 'BERING STRAIT SCHOOL DISTRICT',
        'MATANUSKA-SUSITNA BOROUGH SCHOOL DISTRICT', 'YUPIIT SCHOOL DISTRICT', 'FAYETTE COUNTY SCHOOLS',
        'ROANE COUNTY SCHOOLS', 'LARAMIE COUNTY SCHOOL DISTRICT #1', 'CARBON COUNTY SCHOOL DISTRICT #2',
        'NATRONA COUNTY SCHOOL DISTRICT #1'
    ],
    'Model Selected': ['Transformation']*10,
    'Award_Amount': [471014, 520579, 449592, 641184, 399686, 342189, 260000, 297300, 274000, 431382],
    'Region': ['West', 'West', 'West', 'West', 'West', 'South', 'South', 'West', 'West', 'West']
}

# Create the dataframe
df = pd.DataFrame(data)

# Create a barplot with each Region shown as a different color
sns.barplot(data=df,
         y='Award_Amount',
         x='Model Selected',
         hue='Region')

plt.show()
plt.clf()
