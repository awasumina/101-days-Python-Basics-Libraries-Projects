# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'Music': [5.0, 5.0, 5.0, 4.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0],
    'Techno': [4.0, 1.0, 2.0, 4.0, 1.0, 2.0, 3.0, 5.0, 1.0, 1.0],
    'Movies': [5.0, 4.0, 5.0, 5.0, 5.0, 2.0, 5.0, 5.0, 5.0, 4.0],
    'History': [3.0, 2.0, 3.0, 2.0, 5.0, 4.0, 2.0, 5.0, 5.0, 1.0],
    'Mathematics': [1.0, 2.0, 5.0, 1.0, 1.0, 3.0, 1.0, 1.0, 5.0, 2.0],
    'Finances': [3.0, 1.0, 3.0, 1.0, 1.0, 4.0, 3.0, None, 3.0, 3.0],
    'Age': [21.0, 22.0, 21.0, 30.0, 19.0, None, 17.0, 26.0, 18.0, 19.0],
    'Siblings': [1.0, 1.0, 0.0, 1.0, 1.0, None, 1.0, 1.0, 1.0, 1.0],
    "Parents Advice" : ["Sometimes", "Rarely", "Always", "Often", "Always", "Never", "Rarely", "Sometimes", "Always", "Always"],
    'Gender': ['male', 'female', 'female', 'female', 'female', None, 'male', 'male', 'female', 'female'],
    'Village - town': ['city', 'city', 'city', 'village', 'city', 'village', 'city', 'city', 'city', None]
}

survey_data = pd.DataFrame(data)

sns.set_style("whitegrid")


# Create a count plot of survey responses
category_order = ["Never", "Rarely", "Sometimes",
                  "Often", "Always"]

sns.catplot(x="Parents Advice",
            data=survey_data,
            kind="count",
            order=category_order)

# Show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'Music': [5.0, 5.0, 5.0, 4.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0],
    'Techno': [4.0, 1.0, 2.0, 4.0, 1.0, 2.0, 3.0, 5.0, 1.0, 1.0],
    'Movies': [5.0, 4.0, 5.0, 5.0, 5.0, 2.0, 5.0, 5.0, 5.0, 4.0],
    'History': [3.0, 2.0, 3.0, 2.0, 5.0, 4.0, 2.0, 5.0, 5.0, 1.0],
    'Mathematics': [1.0, 2.0, 5.0, 1.0, 1.0, 3.0, 1.0, 1.0, 5.0, 2.0],
    'Finances': [3.0, 1.0, 3.0, 1.0, 1.0, 4.0, 3.0, None, 3.0, 3.0],
    'Age': [21.0, 22.0, 21.0, 30.0, 19.0, None, 17.0, 26.0, 18.0, 19.0],
    'Siblings': [1.0, 1.0, 0.0, 1.0, 1.0, None, 1.0, 1.0, 1.0, 1.0],
    "Parents Advice" : ["Sometimes", "Rarely", "Always", "Often", "Always", "Never", "Rarely", "Sometimes", "Always", "Always"],
    'Gender': ['male', 'female', 'female', 'female', 'female', None, 'male', 'male', 'female', 'female'],
    'Village - town': ['city', 'city', 'city', 'village', 'city', 'village', 'city', 'city', 'city', None]
}

survey_data = pd.DataFrame(data)

# Set the color palette to "Purples"
sns.set_palette("Purples")


# Create a count plot of survey responses
category_order = ["Never", "Rarely", "Sometimes",
                  "Often", "Always"]

sns.catplot(x="Parents Advice",
            data=survey_data,
            kind="count",
            order=category_order)

# Show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'Music': [5.0, 5.0, 5.0, 4.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0],
    'Techno': [4.0, 1.0, 2.0, 4.0, 1.0, 2.0, 3.0, 5.0, 1.0, 1.0],
    'Movies': [5.0, 4.0, 5.0, 5.0, 5.0, 2.0, 5.0, 5.0, 5.0, 4.0],
    'History': [3.0, 2.0, 3.0, 2.0, 5.0, 4.0, 2.0, 5.0, 5.0, 1.0],
    'Mathematics': [1.0, 2.0, 5.0, 1.0, 1.0, 3.0, 1.0, 1.0, 5.0, 2.0],
    'Finances': [3.0, 1.0, 3.0, 1.0, 1.0, 4.0, 3.0, None, 3.0, 3.0],
    'Age': [21.0, 22.0, 21.0, 30.0, 19.0, None, 17.0, 26.0, 18.0, 19.0],
    'Siblings': [1.0, 1.0, 0.0, 1.0, 1.0, None, 1.0, 1.0, 1.0, 1.0],
    "Parents Advice" : ["Sometimes", "Rarely", "Always", "Often", "Always", "Never", "Rarely", "Sometimes", "Always", "Always"],
    'Gender': ['male', 'female', 'female', 'female', 'female', None, 'male', 'male', 'female', 'female'],
    'Village - town': ['city', 'city', 'city', 'village', 'city', 'village', 'city', 'city', 'city', None]
}

survey_data = pd.DataFrame(data)

# Change the color palette to "RdBu"
sns.set_style("whitegrid")
sns.set_palette("RdBu")


# Create a count plot of survey responses
category_order = ["Never", "Rarely", "Sometimes",
                  "Often", "Always"]

sns.catplot(x="Parents Advice",
            data=survey_data,
            kind="count",
            order=category_order)

# Show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'Music': [5.0, 5.0, 5.0, 4.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0],
    'Techno': [4.0, 1.0, 2.0, 4.0, 1.0, 2.0, 3.0, 5.0, 1.0, 1.0],
    'Movies': [5.0, 4.0, 5.0, 5.0, 5.0, 2.0, 5.0, 5.0, 5.0, 4.0],
    'History': [3.0, 2.0, 3.0, 2.0, 5.0, 4.0, 2.0, 5.0, 5.0, 1.0],
    'Mathematics': [1.0, 2.0, 5.0, 1.0, 1.0, 3.0, 1.0, 1.0, 5.0, 2.0],
    'Finances': [3.0, 1.0, 3.0, 1.0, 1.0, 4.0, 3.0, None, 3.0, 3.0],
    'Age': [21.0, 22.0, 21.0, 30.0, 19.0, None, 17.0, 26.0, 18.0, 19.0],
    'Siblings': [1.0, 1.0, 0.0, 1.0, 1.0, None, 1.0, 1.0, 1.0, 1.0],
    "Parents Advice" : ["Sometimes", "Rarely", "Always", "Often", "Always", "Never", "Rarely", "Sometimes", "Always", "Always"],
    'Gender': ['male', 'female', 'female', 'female', 'female', None, 'male', 'male', 'female', 'female'],
    'Village - town': ['city', 'city', 'city', 'village', 'city', 'village', 'city', 'city', 'city', None]
}

survey_data = pd.DataFrame(data)

# Change the context to "notebook"
sns.set_context("paper")

# Create bar plot
sns.catplot(x="Parents Advice", y="Gender",
            data=survey_data, kind="bar")

# Show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
  
data = {
    'Music': [5.0, 5.0, 5.0, 4.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0],
    'Techno': [4.0, 1.0, 2.0, 4.0, 1.0, 2.0, 3.0, 5.0, 1.0, 1.0],
    'Movies': [5.0, 4.0, 5.0, 5.0, 5.0, 2.0, 5.0, 5.0, 5.0, 4.0],
    'History': [3.0, 2.0, 3.0, 2.0, 5.0, 4.0, 2.0, 5.0, 5.0, 1.0],
    'Mathematics': [1.0, 2.0, 5.0, 1.0, 1.0, 3.0, 1.0, 1.0, 5.0, 2.0],
    'Finances': [3.0, 1.0, 3.0, 1.0, 1.0, 4.0, 3.0, None, 3.0, 3.0],
    'Age': [21.0, 22.0, 21.0, 30.0, 19.0, None, 17.0, 26.0, 18.0, 19.0],
    'Siblings': [1.0, 1.0, 0.0, 1.0, 1.0, None, 1.0, 1.0, 1.0, 1.0],
    "Parents Advice" : ["Sometimes", "Rarely", "Always", "Often", "Always", "Never", "Rarely", "Sometimes", "Always", "Always"],
    'Gender': ['male', 'female', 'female', 'female', 'female', None, 'male', 'male', 'female', 'female'],
    'Village - town': ['city', 'city', 'city', 'village', 'city', 'village', 'city', 'city', 'city', None]
}

survey_data = pd.DataFrame(data)

# Change the context to "notebook"
sns.set_context("notebook")

# Create bar plot
sns.catplot(x="Parents Advice", y="Gender",
            data=survey_data, kind="bar")

# Show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'Music': [5.0, 5.0, 5.0, 4.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0],
    'Techno': [4.0, 1.0, 2.0, 4.0, 1.0, 2.0, 3.0, 5.0, 1.0, 1.0],
    'Movies': [5.0, 4.0, 5.0, 5.0, 5.0, 2.0, 5.0, 5.0, 5.0, 4.0],
    'History': [3.0, 2.0, 3.0, 2.0, 5.0, 4.0, 2.0, 5.0, 5.0, 1.0],
    'Mathematics': [1.0, 2.0, 5.0, 1.0, 1.0, 3.0, 1.0, 1.0, 5.0, 2.0],
    'Finances': [3.0, 1.0, 3.0, 1.0, 1.0, 4.0, 3.0, None, 3.0, 3.0],
    'Age': [21.0, 22.0, 21.0, 30.0, 19.0, None, 17.0, 26.0, 18.0, 19.0],
    'Siblings': [1.0, 1.0, 0.0, 1.0, 1.0, None, 1.0, 1.0, 1.0, 1.0],
    "Parents Advice" : ["Sometimes", "Rarely", "Always", "Often", "Always", "Never", "Rarely", "Sometimes", "Always", "Always"],
    'Gender': ['male', 'female', 'female', 'female', 'female', None, 'male', 'male', 'female', 'female'],
    'Village - town': ['city', 'city', 'city', 'village', 'city', 'village', 'city', 'city', 'city', None]
}

survey_data = pd.DataFrame(data)

# Change the context to "notebook"
sns.set_context("notebook")

# Create bar plot
sns.catplot(x="Parents Advice", y="Gender",
            data=survey_data, kind="bar")

# Show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'Music': [5.0, 5.0, 5.0, 4.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0],
    'Techno': [4.0, 1.0, 2.0, 4.0, 1.0, 2.0, 3.0, 5.0, 1.0, 1.0],
    'Movies': [5.0, 4.0, 5.0, 5.0, 5.0, 2.0, 5.0, 5.0, 5.0, 4.0],
    'History': [3.0, 2.0, 3.0, 2.0, 5.0, 4.0, 2.0, 5.0, 5.0, 1.0],
    'Mathematics': [1.0, 2.0, 5.0, 1.0, 1.0, 3.0, 1.0, 1.0, 5.0, 2.0],
    'Finances': [3.0, 1.0, 3.0, 1.0, 1.0, 4.0, 3.0, None, 3.0, 3.0],
    'Age': [21.0, 22.0, 21.0, 30.0, 19.0, None, 17.0, 26.0, 18.0, 19.0],
    'Siblings': [1.0, 1.0, 0.0, 1.0, 1.0, None, 1.0, 1.0, 1.0, 1.0],
    "Parents Advice" : ["Sometimes", "Rarely", "Always", "Often", "Always", "Never", "Rarely", "Sometimes", "Always", "Always"],
    'Gender': ['male', 'female', 'female', 'female', 'female', None, 'male', 'male', 'female', 'female'],
    'Village - town': ['city', 'city', 'city', 'village', 'city', 'village', 'city', 'city', 'city', None]
}

survey_data = pd.DataFrame(data)

# Change the context to "poster"
sns.set_context("poster")

# Create bar plot
sns.catplot(x="Parents Advice", y="Gender",
            data=survey_data, kind="bar")

# Show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'Music': [5.0, 5.0, 5.0, 4.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0],
    'Techno': [4.0, 1.0, 2.0, 4.0, 1.0, 2.0, 3.0, 5.0, 1.0, 1.0],
    'Movies': [5.0, 4.0, 5.0, 5.0, 5.0, 2.0, 5.0, 5.0, 5.0, 4.0],
    'History': [3.0, 2.0, 3.0, 2.0, 5.0, 4.0, 2.0, 5.0, 5.0, 1.0],
    'Mathematics': [1.0, 2.0, 5.0, 1.0, 1.0, 3.0, 1.0, 1.0, 5.0, 2.0],
    'Finances': [3.0, 1.0, 3.0, 1.0, 1.0, 4.0, 3.0, None, 3.0, 3.0],
    'Age': [21.0, 22.0, 21.0, 30.0, 19.0, None, 17.0, 26.0, 18.0, 19.0],
    'Siblings': [1.0, 1.0, 0.0, 1.0, 1.0, None, 1.0, 1.0, 1.0, 1.0],
    "Parents Advice" : ["Sometimes", "Rarely", "Always", "Often", "Always", "Never", "Rarely", "Sometimes", "Always", "Always"],
    'Gender': ['male', 'female', 'female', 'female', 'female', None, 'male', 'male', 'female', 'female'],
    'Village - town': ['city', 'city', 'city', 'village', 'city', 'village', 'city', 'city', 'city', None]
}

survey_data = pd.DataFrame(data)

# Set the style to "darkgrid"
sns.set_style("darkgrid")

# Set a custom color palette
sns.set_palette(["#39A7D0","#36ADA4"])

# Create bar plot
sns.catplot(x="Gender", y="Age",
            data=survey_data, kind="box")

# Show plot
plt.show()
